# %% [markdown]
# # Statistics Challenge (Optional)

# %% [markdown]
# Use the `orders.csv` dataset in the same directory to complete this challenge.
#
# **Background**:
#
# There are exactly 100 sneaker shops on a sneaker retailing website, and each of these shops sells only one model of shoe. We want to do some analysis of the average order value (AOV). When we look at orders data over a 30 day window, we naively calculate an AOV of $3145.13. Given that we know these shops are selling sneakers, a relatively affordable item, something seems wrong with our analysis.
#
# **Questions**:
#
# - What went wrong with this metric (AOV) and the current analysis in general. Support your answers with appropriate visualizations.
#
# - Propose a new metric that better represents the behavior of the stores' customers. Why are these metrics better and what are their values?
#
# - Using the `created_at` column as a proxy for the date and time of order creation, provide a brief analysis of the trends in the customers' purchasing behavior.
#
# Show all of your work in this notebook.

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv("orders.csv")

print(df["order_value"].describe())
# Out:
# count      5000.000000
# mean       3145.128000
# std       41282.539349
# min          90.000000
# 25%         163.000000
# 50%         284.000000
# 75%         390.000000
# max      704000.000000
# Name: order_value, dtype: float64

# %% [markdown]
# We can see that there is at least 1 extreme outlier. A pair of shoes sold for over $70k which makes the average higher than it would be otherwise. Even a 75th percentile pair of shoes was only $390.

# %% [markdown]
# A better metric would be to look at the median price, which is equivalent to the 50 percentile value given by describe. This would be better because it is going to be a normal selling price, half sold for more, half sold for less. Better yet would be to just look at the output of describe and see what the min, max, 25 percentile, 50 percentile, and 75 percentile sale prices were.

# %%
df.plot.hist(x="created_at", y="total_items")
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
df["created_at"] = pd.to_datetime(df["created_at"])
df.plot.scatter(x="created_at", y="order_value")
# Out:
# <AxesSubplot: xlabel='created_at', ylabel='order_value'>

# %% [markdown]
# Most orders are small orders with some large ones. I would guess that small orders were placed by individuals, and large orders were placed by businesses.
